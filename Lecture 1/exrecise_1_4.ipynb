# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from helpers import *

# %%
img = cv2.imread('Images/dots.jpg', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

print(img.shape)
show_histogram(img)
plt.imshow(img, cmap='gray')
# Out:
# (336, 576)

# %%
A = 2.4
B = -35
T = 85

new_img = contrast_brightness(img, A, B)
show_histogram(new_img)
new_img = cv2.threshold(img, T, 255, cv2.THRESH_BINARY_INV)[1]

plt.imshow(new_img, cmap='gray')
