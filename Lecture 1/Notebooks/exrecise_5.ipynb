# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from helpers import *

# %%
img = cv2.imread('../Images/Einstein.tif', 1)
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

show_histogram(img)
plt.imshow(img, cmap='gray')

# %%
alpha = 2.7
beta = -200

new_img = contrast_brightness(img, alpha, beta)

show_histogram(new_img)
plt.imshow(new_img, cmap='gray')
