# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
from helpers import *

# %%
img = cv2.imread('../Images/enhance-me.jpg', 1)
#img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

h, w, c = img.shape
print(h, w)
plt.imshow(img, cmap='gray')
# Out:
# 224 192

# %%
show_histogram(img)

# %%
a = 6
b = 40

new_img = contrast_brightness(img, a, b)
new_img = cv2.fastNlMeansDenoising(new_img, None, 10, 7, 21)

plt.imshow(new_img, cmap='gray')

# %%
show_histogram(new_img)
