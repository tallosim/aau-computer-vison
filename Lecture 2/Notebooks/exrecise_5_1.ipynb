# %%
import cv2
from matplotlib import pyplot as plt
import matplotlib.patches as patches
import numpy as np
from helpers import *

# %%
image = cv2.imread('../Images/lion.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

show_histograms(image)
plt.imshow(image, cmap='gray')

# %%
KERNEL_SIZE = 1

sobelx = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=KERNEL_SIZE)
sobely = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=KERNEL_SIZE)

sobel = np.abs(sobelx) + np.abs(sobely)

plt.imshow(sobel, cmap='gray')

# %%
T = 45

mask = cv2.threshold(sobel, T, 255, cv2.THRESH_BINARY)[1]

plt.imshow(mask, cmap='gray')
